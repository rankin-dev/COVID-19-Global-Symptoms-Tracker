# %%
import pandas as pd
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="white")
d = pd.read_csv("combined_americas.csv")
corr = d.corr()
sns.heatmap(d.corr())
# Out:
# <AxesSubplot:>
